# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.rand(10)      #1행의 10열의 행렬을 만들고 0~1사이의 값들로 채워넣음
# Out:
# array([0.40277564, 0.85074007, 0.92400139, 0.5724491 , 0.2740157 ,
#        0.6418385 , 0.30722903, 0.47062224, 0.3818261 , 0.1945201 ])

# %%
np.random.rand(3,6)     #3행 6열의 행렬을 만들고 0~1사이의 값들로 채워넣음
# Out:
# array([[0.31653808, 0.55774515, 0.14539426, 0.83024612, 0.14161236,
#         0.23642926],
#        [0.23398564, 0.98630126, 0.2274798 , 0.08206745, 0.86437965,
#         0.50975593],
#        [0.57373455, 0.01348037, 0.6275198 , 0.77091482, 0.19834296,
#         0.12358483]])

# %%
x = np.arange(0.0, 35.0, 5.0)     #x축의 값이 0~35미만이고 간격은 5.0 씩
y = (x*1.5) + 50
'''+ np.random.rand(20)'''
plt.bar(x,y)
plt.show()
