# %% [markdown]
# Colab Inplementation for the paper
# #Lightweight Multi-Branch Network for Person Re-Identification
# [PDF](https://arxiv.org/pdf/2101.10774.pdf) and [Code](https://github.com/jixunbo/LightMBN)

# %% [markdown]
# **This Colab notebook helps you to re-inplement our work easily online, you can see the state-of-the-art performance.**
#
# *Check if you are using GPU*
#
# *if not, Edit > Notebook settings or Runtime>Change runtime type and select GPU as Hardware accelerator.*

# %%
# !nvidia-smi
# Out:
# Wed Mar 23 07:43:56 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# 1. Download Datasets

# %%
# !git clone https://github.com/jixunbo/ReIDataset.git
# Out:
# Cloning into 'ReIDataset'...
# remote: Enumerating objects: 180784, done.
# remote: Total 180784 (delta 0), reused 0 (delta 0), pack-reused 180784
# Receiving objects: 100% (180784/180784), 3.22 GiB | 33.89 MiB/s, done.
# Resolving deltas: 100% (7792/7792), done.
# Checking out files: 100% (227554/227554), done.

# %% [markdown]
# 2. Download codes.

# %%
# !git clone https://github.com/jixunbo/LightMBN
# Out:
# Cloning into 'LightMBN'...
# remote: Enumerating objects: 297, done.
# remote: Counting objects: 100% (296/296), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 297 (delta 186), reused 268 (delta 174), pack-reused 1
# Receiving objects: 100% (297/297), 1.45 MiB | 10.24 MiB/s, done.
# Resolving deltas: 100% (186/186), done.

# %% [markdown]
# 3. Run

# %%
# !python /content/LightMBN/main.py --datadir /content/ReIDataset --data_train market1501 --data_test market1501 --model LMBN_n --batchid 6 --batchimage 8 --batchtest 32 --test_every 20 --epochs 5 --loss 0.5*CrossEntropy+0.5*MSLoss --margin 0.7 --nGPU 1 --lr 6e-4 --optimizer ADAM --random_erasing --feats 512 --save '' --if_labelsmooth --w_cosine_annealing
# Out:
# running build_ext
# Neptune is not installed.
# Experiment results will be saved in /content/LightMBN/experiment/2022-03-23-07:56:30
# Building train transforms ...
# + resize to 384x128
# + random flip
# + random crop (enlarge to 403x134 and crop 384x128)
# + to torch tensor of range [0, 1]
# + normalization (mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# + random erase
# Building test transforms ...
# + resize to 384x128
# + to torch tensor of range [0, 1]
# + normalization (mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# => Loading train (source) dataset
# /content/LightMBN/data_v2/datasets/image/market1501.py:42: UserWarning: The current data structure is deprecated. Please put data folders such as "bounding_box_train" under "Market-1501-v15.09.15".
#   warnings.warn('The current data structure is deprecated. Please '
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# => Loading test (target) dataset
#
#
#   **************** Summary ****************
#   train            : ['market1501']
#   # train datasets : 1
#   # train ids      : 751
#   # train images   : 12936
#   # train cameras  : 6
#   test             : ['market1501']
#   # query images   : 3368
#   # gallery images : 15913
#   *****************************************
#
#
# [INFO] Building LMBN_n model... Time used: 0 m 1 s
# Successfully loaded imagenet pretrained weights from "/root/.cache/torch/checkpoints/osnet_x1_0_imagenet.pth"
# [INFO] Making loss... Time used: 0 m 3 s
# [INFO] Label Smoothing On. Time used: 0 m 3 s
# [INFO] Model parameters: 9348768 flops: 2430837088 Time used: 0 m 6 s
# [INFO] GPU: Tesla K80 Time used: 0 m 6 s
# [INFO] Starting from epoch 1 Time used: 0 m 6 s
# [INFO] Epoch: 1	Learning rate: 6.00e-05   Time used: 0 m 6 s
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [INFO] [1/5]	234/234	[CrossEntropy: 23.048737][MSLoss: 1.706322][Total: 24.755056] Time used: 8 m 37 s
# [INFO] Epoch: 2	Learning rate: 1.20e-04   Time used: 8 m 37 s
# [INFO] [2/5]	234/234	[CrossEntropy: 22.131779][MSLoss: 1.559689][Total: 23.691463] Time used: 17 m 2 s
# [INFO] Epoch: 3	Learning rate: 1.80e-04   Time used: 17 m 2 s
# [INFO] [3/5]	234/234	[CrossEntropy: 20.422665][MSLoss: 1.429107][Total: 21.851772] Time used: 25 m 28 s
# [INFO] Epoch: 4	Learning rate: 2.40e-04   Time used: 25 m 28 s
# [INFO] [4/5]	235/235	[CrossEntropy: 18.663210][MSLoss: 1.348091][Total: 20.011295] Time used: 33 m 55 s
# [INFO] Epoch: 5	Learning rate: 3.00e-04   Time used: 33 m 55 s
# [INFO] [5/5]	234/234	[CrossEntropy: 16.981146][MSLoss: 1.299623][Total: 18.280769] Time used: 42 m 20 s
#
# [INFO] Test: Time used: 42 m 20 s
# [INFO] mAP: 0.6218 rank1: 0.8103 rank3: 0.8895 rank5: 0.9145 rank10: 0.9454 (Best: 0.6218 @epoch 5.0) Time used: 49 m 28 s
# [INFO] Checkpoint saved to "/content/LightMBN/experiment/2022-03-23-07:56:30/model-latest.pth" Time used: 49 m 29 s

# %% [markdown]
# 4. Test using pretrained models

# %%
import gdown
gdown.download("https://drive.google.com/uc?export=download&id=1BeXrNluAvaLsNvXyEK0WFHM6kDw3r8ND",'PRETRAIN.zip',True)
# !unzip PRETRAIN.zip
# Out:
# Access denied with the following error:
# unzip:  cannot find or open PRETRAIN.zip, PRETRAIN.zip.zip or PRETRAIN.zip.ZIP.
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?export=download&id=1BeXrNluAvaLsNvXyEK0WFHM6kDw3r8ND

# %%
# !python /content/LightMBN/main.py --test_only --config '/content/PRETRAIN/cfg_lmbn_n_cuhk03_d.yaml' --pre_train '/content/PRETRAIN/lmbn_n_cuhk03_d.pth'
# Out:
# running build_ext
# Neptune is not installed.
# Traceback (most recent call last):
#   File "/content/LightMBN/main.py", line 19, in <module>
#     with open(args.config, 'r') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/PRETRAIN/cfg_lmbn_n_cuhk03_d.yaml'
